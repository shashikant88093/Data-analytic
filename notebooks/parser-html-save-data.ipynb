# %%
# !pip install requests
# !pip install lxml
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: C:\Users\shash\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
# ...

# %%
import pandas as pd
import requests

url = "https://www.simplilearn.com/tutorials/python-tutorial/python-internet-access-using-urllib-request-and-urlopen"
r = requests.get(url)
wiki_tables = pd.read_html(r.text,header=0)
print(f"Total tables found: {len(wiki_tables)}")

# Display all tables one by one
for idx, table in enumerate(wiki_tables):
    print(f"\n--- Table {idx + 1} ---")
    display(table)
# Out:
# Total tables found: 2
#
# --- Table 1 ---
# C:\Users\shash\AppData\Local\Temp\ipykernel_13828\2045859069.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   wiki_tables = pd.read_html(r.text,header=0)
#                 Python for Beginners  Enroll Now!
# 0  Python Libraries for Data Science  Enroll Now!
# 1        Python Pandas Basics Course  Enroll Now!
# 2     Getting Python Interview Ready  Enroll Now!
# 3      Machine Learning using Python  Enroll Now!
# --- Table 2 ---
#                                         Program Name   Duration         Fees
# 0  Professional Certificate Program in Blockchain...   4 Months  â¹1,10,000
# 1  e-Post Graduate Diploma (ePGD) in IC Design in...  12 months    â¹53,100
# 2  Managing Software ArchitectureCohort Starts: 6...    8 weeks  â¹1,50,000
# ...
